# %%
# @Установка библиотеки OpenAI
# !pip install openai==0.28.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 1.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.1.1
#     Uninstalling openai-1.1.1:
#       Successfully uninstalled openai-1.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# ...

# %%
import os
import openai
openai.api_key = "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"
openai.ChatCompletion.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "user", "content": "Hello ChatGPT, does this work?"}
  ]
  )
# Out:
# <OpenAIObject chat.completion id=chatcmpl-8FIvdkptX7IlHHJF9Yp1W4I38kqN7 at 0x7e677440c860> JSON: {
#   "id": "chatcmpl-8FIvdkptX7IlHHJF9Yp1W4I38kqN7",
#   "object": "chat.completion",
#   "created": 1698658373,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "Hello! Yes, ChatGPT is designed to interact and respond to user inputs. How may I assist you today?"
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 16,
#     "completion_tokens": 24,
#     "total_tokens": 40
#   }
# }

# %%
import os
import openai
openai.api_key = "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"
response = openai.ChatCompletion.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "user", "content": "Hello ChatGPT, does this work?"}
  ]
  )
print(response.choices[0].message.content)
# Out:
# Hello! I am ChatGPT, a language model developed by OpenAI. I am designed to understand and generate human-like text responses. Feel free to ask me anything or share your thoughts and I'll do my best to help you. How can I assist you today?

# %%
import os
import openai

openai.api_key = "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"

def chatWithGPT(prompt):
  completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo",
  messages=[
  {"role": "user", "content": prompt}
  ]
  )
  return print(completion.choices[0].message.content)
chatWithGPT("is it a good idea to start learning python?")
# Out:
# Yes, it is a good idea to start learning Python. Python is a versatile and beginner-friendly programming language that is widely used in various fields such as web development, data analysis, artificial intelligence, and automation. It has a simple syntax and a large community of developers who contribute to its libraries and frameworks, making it easier to learn and use. Additionally, Python is in high demand in the job market, so learning it can increase your career opportunities.

# %%
import os
import openai
openai.api_key = "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"
def fixMyCode(code):
  completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "user", "content": "find error in my python script below and fix it: " + code}
  ]
  )
  return print(completion.choices[0].message.content)

fixMyCode("""
def some_function():
    print("I'm going to sleep")
    time.sleep(10)
    print("I'm awake again")
some_function()
""")
# Out:
# To fix the error, you need to import the `time` module. Corrected code:
#
# ```python
# import time
#
# def some_function():
#     print("I'm going to sleep")
#     time.sleep(10)
#     print("I'm awake again")
#
# some_function()
# ```

# %%
import IPython
import os
import openai
openai.api_key = "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"
def createImageWithGPT(prompt):
  completion = openai.Image.create(
  prompt=prompt,
  n=1,
  size="512x512"
  )
  return IPython.display.HTML("<img src =" + completion.data[0].url + ">")
createImageWithGPT("Monkey driving a skateboard")
# Out:
# <img src =https://oaidalleapiprodscus.blob.core.windows.net/private/org-mVQfe0EnzilAk1eEPGTny0gW/user-AHBgPzDo9tugIsHVYGqHP14Q/img-B4wQsMPSF5YYJsn8BFZYWTdE.png?st=2023-10-30T12%3A25%3A28Z&se=2023-10-30T14%3A25%3A28Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-10-30T04%3A00%3A15Z&ske=2023-10-31T04%3A00%3A15Z&sks=b&skv=2021-08-06&sig=b2hRqMZg%2Brpe86Tv1xqC14pZXSmXXyQeoUyzqROWE/M%3D>

# %% [markdown]
# ## **Решение задачи с помощью ChatGPT**

# %%
import os
import openai
openai.api_key = "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"
def fixMyCode(code):
  completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "user", "content": code}
  ]
  )
  return print(completion.choices[0].message.content)

message = 'Напиши мне телеграм-бот для создания очереди, чтобы пользователи могли встать в очередь, уходить когда им хочется, при этом они будет знать свои места и порядок очереди'
fixMyCode(message)
# Out:
# Напиши мне телеграм-бот для создания очереди, чтобы пользователи могли встать в очередь, уходить когда им хочется, при этом они будет знать свои места и порядок очереди
# Конечно! Вот пример кода для телеграм-бота на языке Python, который позволяет пользователям встать в очередь, сохраняя их порядок и позволяя им покинуть очередь по желанию:
#
# ```python
# import telebot
#
# bot_token = "YOUR_BOT_TOKEN"
# bot = telebot.TeleBot(bot_token)
#
# queue = []  # Очередь
#
# @bot.message_handler(commands=['start'])
# def send_welcome(message):
#     bot.reply_to(message, "Привет! Чтобы встать в очередь, отправь /join. Чтобы уйти из очереди, отправь /leave.")
#
# @bot.message_handler(commands=['join'])
# def join_queue(message):
#     user_id = message.from_user.id
#     if user_id not in queue:  # Проверяем, что пользователь не в очереди
#         queue.append(user_id)
#         bot.reply_to(message, f"Вы встали в очередь. Ваш номер в очереди: {len(queue)}")
#     else:
# ...
